# %%
import pandas as pd
import numpy as np
import  warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Car_sales.csv")
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.Horsepower.plot.hist(figsize=(6,3),cmap='brg');

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    object
# ...

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    object
# ...

# %%
df.Sales_in_thousands.plot.box(figsize=(10,15),cmap="gist_earth")
# Out:
# <AxesSubplot:>

# %%
ef outlier(col):
    Q3, Q1= np.nanpercentile(col,[75,25])
    iqr=Q3-Q1
    ul=Q3+1.5*iqr
    ll=Q1-1.5*iqr
    return ul, ll
# Out:
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_10428\890445713.py", line 1
#     ef outlier(col):
#        ^
# SyntaxError: invalid syntax

# %%
for column in df.columns:
    if df[column].dtype !="object":
        ul,ll=outlier(df[column])
        df[column]=np.where((df[column]>ul)|(df[column]<ll),np.nan,df[column])

# %%
for i in df.columns:
    if df[i].dtype !="object":
        sns.boxplot(y=df[i],color="green")
        plt.show()

# %%
df.Horsepower.plot.box(figsize=(15,25));

# %%
df.plot.box(figsize=(22,4),subplots=True,cmap="Reds");

# %%
df.plot.hist(figsize=(6,18),subplots=True);
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.sort_values(by='__year_resale_value').plot.line('__year_resale_value','Price_in_thousands',figsize=(6,3));

# %%
df.Manufacturer.value_counts().plot.bar(figsize=(6,2),cmap='jet')
# Out:
# <AxesSubplot:>

# %%
df.plot.area("Manufacturer","Price_in_thousands")
# Out:
# <AxesSubplot:xlabel='Manufacturer'>

# %%
df.sample()
# Out:
#    Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 45        Dodge  Caravan             181.749               12.025
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 45          Car              19.565          2.4       150.0      113.3
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 45   76.8   186.3        3.533           20.0             24.0      9/1/2011
#
#     Power_perf_factor
# 45             61.227

# %%
df.sort_values(by="Price_in_thousands")[:6].plot.barh('Model','Power_perf_factor')
# Out:
# <AxesSubplot:ylabel='Model'>

# %%
df.sort_values("Vehicle_type")[:5].plot.scatter('Latest_Launch',"Sales_in_thousands",figsize=(6,3),cmap='prism');

# %%
df.plot.box(figsize=(22,5));

# %% [markdown]
# ### pie plot

# %%
df.sort_values(by="Engine_size",ascending=False)[:50].Engine_size.plot.pie();

# %% [markdown]
# ### kde plot

# %%
df.plot.kde(figsize=(5,3.5),cmap='prism');

# %%
df.plot.kde(figsize=(12,10),subplots=True);
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.plot.hexbin('Curb_weight','Fuel_capacity',cmap='autumn');
