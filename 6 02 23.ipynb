# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("titanic.csv")
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ### groping

# %%
df1=df.groupby(['Hometown'])['Survived']
df1.sum()
# Out:
# Hometown
# Abbeyleix, Laois, Ireland[note 1]    0.0
# Abercynon, Glamorgan, Wales          0.0
# Aberdeen, Aberdeenshire, Scotland    1.0
# Aberdeen, Washington, US             0.0
# Aclare, Sligo, Ireland               0.0
#                                     ...
# Örsjö, Kalmar, Sweden                0.0
# Östra Sallerup, Skåne, Sweden        0.0
# Øyer, Norway                         0.0
# Široka Kula, Croatia                 0.0
# Ḑuhūr ash Shuwayr, Lebanon           4.0
# Name: Survived, Length: 566, dtype: float64

# %% [markdown]
# ### multiple

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ### multipile coloumn

# %%
df2=df.groupby(['Sex'])['Age','Survived']
df2.sum()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8000\532647106.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2=df.groupby(['Sex'])['Age','Survived']
#              Age  Survived
# Sex
# female  11130.59     233.0
# male    20125.08     109.0

# %% [markdown]
# ### multiple group

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df3=df.groupby(['Sex','Pclass'],as_index=False)['Survived']
df3.sum()
# Out:
#       Sex  Pclass  Survived
# 0  female       1      91.0
# 1  female       2      70.0
# 2  female       3      72.0
# 3    male       1      45.0
# 4    male       2      17.0
# 5    male       3      47.0

# %% [markdown]
# ### multiple function

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df4=df.groupby(['Sex'])['Survived'].agg(['mean','sum'])
df4
# Out:
#             mean    sum
# Sex
# female  0.742038  233.0
# male    0.188908  109.0

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.groupby(['Sex'])['Age','Fare'].agg(['mean','sum'])
# Out:
#               Age                 Fare
#              mean       sum       mean         sum
# Sex
# female  28.687088  11130.59  46.198097  21528.3130
# male    30.585228  20125.08  26.154601  22022.1739

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.groupby(['Name'])['Survived'].sum()
# Out:
# Name
# Abbing, Mr. Anthony                              0.0
# Abbott, Master. Eugene Joseph                    0.0
# Abbott, Mr. Rossmore Edward                      0.0
# Abbott, Mrs. Stanton (Rosa Hunt)                 1.0
# Abelseth, Miss. Karen Marie                      0.0
#                                                 ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)    0.0
# van Billiard, Master. James William              0.0
# van Billiard, Master. Walter John                0.0
# van Billiard, Mr. Austin Blyler                  0.0
# van Melkebeke, Mr. Philemon                      0.0
# Name: Survived, Length: 1307, dtype: float64

# %%
df.groupby(['Parch'])['Fare','Survived'].agg(['mean','sum'])
# Out:
#              Fare              Survived
#              mean         sum      mean    sum
# Parch
# 0       26.329820  26356.1494  0.343658  233.0
# 1       50.078358   8513.3209  0.550847   65.0
# 2       61.346275   6932.1291  0.500000   40.0
# 3       86.688537    693.5083  0.600000    3.0
# 4      104.723617    628.3417  0.000000    0.0
# 5       32.356250    194.1375  0.200000    1.0
# 6       46.900000     93.8000  0.000000    0.0
# 9       69.550000    139.1000       NaN    0.0
