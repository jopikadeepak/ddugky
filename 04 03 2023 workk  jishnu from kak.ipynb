# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("laptops.csv")
df
# Out:
#      Unnamed: 0                                              title      price  \
# 0             0  DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/...    ₹37,990
# 1             1  HP 14s Intel Core i3 11th Gen - (8 GB/256 GB S...    ₹35,490
# 2             2  Lenovo V15 G2 Core i3 11th Gen - (8 GB/512 GB ...    ₹33,999
# 3             3  HP 15s Intel Core i3 12th Gen - (8 GB/512 GB S...    ₹45,490
# 4             4  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹33,990
# ..          ...                                                ...        ...
# 915         915  Lenovo Intel Core i7 12th Gen - (16 GB/512 GB ...  ₹1,19,990
# 916         916  DELL Core i5 11th Gen - (16 GB/512 GB SSD/Wind...    ₹68,990
# 917         917  DELL Inspiron Pentium Quad Core - (8 GB/256 GB...    ₹35,990
# 918         918  ASUS Vivobook X515EA Core i3 11th Gen - (8 GB/...    ₹36,990
# 919         919  HP Pavilion Intel Core i7 11th Gen - (16 GB/51...    ₹89,999
#
# ...

# %%
df.shape
# Out:
# (920, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   920 non-null    int64
#  1   title        920 non-null    object
#  2   price        920 non-null    object
#  3   discount     831 non-null    object
#  4   Processor    920 non-null    object
#  5   RAM          920 non-null    object
#  6   OS           920 non-null    object
#  7   SSD          920 non-null    object
#  8   Display      920 non-null    object
#  9   In_build_sw  357 non-null    object
#  10  warranty     906 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 79.2+ KB

# %%
df.isnull().mean()*100
# Out:
# Unnamed: 0      0.000000
# title           0.000000
# price           0.000000
# discount        9.673913
# Processor       0.000000
# RAM             0.000000
# OS              0.000000
# SSD             0.000000
# Display         0.000000
# In_build_sw    61.195652
# warranty        1.521739
# dtype: float64

# %%
df.drop(columns="In_build_sw",inplace=True)

# %%
df
# Out:
#      Unnamed: 0                                              title      price  \
# 0             0  DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/...    ₹37,990
# 1             1  HP 14s Intel Core i3 11th Gen - (8 GB/256 GB S...    ₹35,490
# 2             2  Lenovo V15 G2 Core i3 11th Gen - (8 GB/512 GB ...    ₹33,999
# 3             3  HP 15s Intel Core i3 12th Gen - (8 GB/512 GB S...    ₹45,490
# 4             4  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹33,990
# ..          ...                                                ...        ...
# 915         915  Lenovo Intel Core i7 12th Gen - (16 GB/512 GB ...  ₹1,19,990
# 916         916  DELL Core i5 11th Gen - (16 GB/512 GB SSD/Wind...    ₹68,990
# 917         917  DELL Inspiron Pentium Quad Core - (8 GB/256 GB...    ₹35,990
# 918         918  ASUS Vivobook X515EA Core i3 11th Gen - (8 GB/...    ₹36,990
# 919         919  HP Pavilion Intel Core i7 11th Gen - (16 GB/51...    ₹89,999
#
# ...

# %%
df.drop(columns="Unnamed: 0",inplace=True)

# %%
df
# Out:
#                                                  title      price  \
# 0    DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/...    ₹37,990
# 1    HP 14s Intel Core i3 11th Gen - (8 GB/256 GB S...    ₹35,490
# 2    Lenovo V15 G2 Core i3 11th Gen - (8 GB/512 GB ...    ₹33,999
# 3    HP 15s Intel Core i3 12th Gen - (8 GB/512 GB S...    ₹45,490
# 4    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹33,990
# ..                                                 ...        ...
# 915  Lenovo Intel Core i7 12th Gen - (16 GB/512 GB ...  ₹1,19,990
# 916  DELL Core i5 11th Gen - (16 GB/512 GB SSD/Wind...    ₹68,990
# 917  DELL Inspiron Pentium Quad Core - (8 GB/256 GB...    ₹35,990
# 918  ASUS Vivobook X515EA Core i3 11th Gen - (8 GB/...    ₹36,990
# 919  HP Pavilion Intel Core i7 11th Gen - (16 GB/51...    ₹89,999
#
#              discount                                          Processor  \
# 0      ₹58,48935% off  Processor: Intel i3-1115G4 (Base- 1.7 GHz & Tu...
# ...

# %%
df.isnull().mean()*100
# Out:
# title        0.000000
# price        0.000000
# discount     9.673913
# Processor    0.000000
# RAM          0.000000
# OS           0.000000
# SSD          0.000000
# Display      0.000000
# warranty     1.521739
# dtype: float64

# %%
A=df["discount"].mode()[0]
A
# Out:
# '₹54,99914% off'

# %%
df.describe()
# Out:
#                                                     title    price  \
# count                                                 920      920
# unique                                                846      469
# top     Infinix X1 Slim Series Core i5 10th Gen - (8 G...  ₹54,990
# freq                                                    4       17
#
#               discount                           Processor            RAM  \
# count              831                                 920            920
# unique             763                                  92             57
# top     ₹74,99026% off  Intel Core i5 Processor (11th Gen)  8 GB DDR4 RAM
# freq                 4                                  95            357
#
#                                         OS         SSD  \
# count                                  920         920
# unique                                  45          52
# top     64 bit Windows 11 Operating System  512 GB SSD
# ...

# %%
df["discount"].replace(np.nan,A,inplace=True)

# %%
df.isnull().mean()*100
# Out:
# title        0.000000
# price        0.000000
# discount     0.000000
# Processor    0.000000
# RAM          0.000000
# OS           0.000000
# SSD          0.000000
# Display      0.000000
# warranty     1.521739
# dtype: float64

# %%
b=df["warranty"].mode()[0]
b
# Out:
# '1 Year Onsite Warranty'

# %%
df["warranty"].replace(np.nan,b,inplace=True)

# %%
for i in df.columns:
    if i =="object":
        df=df.columns.astype("string")
        print(df)

# %%
df["warranty"]=df["warranty"].astype("string")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      920 non-null    object
#  1   price      920 non-null    object
#  2   discount   920 non-null    object
#  3   Processor  920 non-null    object
#  4   RAM        920 non-null    object
#  5   OS         920 non-null    object
#  6   SSD        920 non-null    object
#  7   Display    920 non-null    object
#  8   warranty   920 non-null    string
# dtypes: object(8), string(1)
# memory usage: 64.8+ KB

# %%
for i in df.columns:
    if df[columns].dtype =="object":
        df[columns]= df[columns].astype("string")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5784\1407466980.py in <module>
#       1 for i in df.columns:
# ----> 2     if df[columns].dtype =="object":
#       3         df[columns]= df[columns].astype("string")
#
# NameError: name 'columns' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      920 non-null    object
#  1   price      920 non-null    object
#  2   discount   920 non-null    object
#  3   Processor  920 non-null    object
#  4   RAM        920 non-null    object
#  5   OS         920 non-null    object
#  6   SSD        920 non-null    object
#  7   Display    920 non-null    object
#  8   warranty   920 non-null    string
# dtypes: object(8), string(1)
# memory usage: 64.8+ KB
