# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("netflix_titles_2021.csv")

# %%
df.tail(20)
# Out:
#      show_id     type                           title            director  \
# 700     s701  TV Show              Record of Ragnarok                 NaN
# 397     s398  TV Show                 Feels Like Ishq                 NaN
# 503     s504  TV Show                        The Mire        Jan Holoubek
# 35       s36    Movie  The Father Who Moves Mountains        Daniel Sandu
# 272     s273  TV Show       Fast & Furious Spy Racers                 NaN
# 82       s83  TV Show                         Lucifer                 NaN
# 1370   s1371    Movie                         The Dig         Simon Stone
# 912     s913    Movie     The Circle - The Afterparty                 NaN
# 696     s697  TV Show                    Black Summer                 NaN
# 833     s834  TV Show                     Black Space                 NaN
# 734     s735  TV Show                           Lupin                 NaN
# 1301   s1302  TV Show                 Behind Her Eyes                 NaN
# ...

# %%
df.head(10)
# Out:
#      show_id     type                                             title  \
# 4250   s4251  TV Show                 Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                    Prelude to War
# 8205   s8206    Movie                              The Battle of Midway
# 8763   s8764    Movie                   WWII: Report from the Aleutians
# 8739   s8740    Movie                Why We Fight: The Battle of Russia
# 8660   s8661    Movie     Undercover: How to Operate Behind Enemy Lines
# 8419   s8420    Movie  The Memphis Belle: A Story of a\nFlying Fortress
# 8436   s8437    Movie                                 The Negro Soldier
# 8640   s8641    Movie                                  Tunisian Victory
# 1331   s1332  TV Show               Five Came Back: The Reference Films
#
#                                                director  \
# 4250                                                NaN
# 7790                                        Frank Capra
# ...

# %%
df.sample(10) #taking the sample of dataset
# Out:
#      show_id     type                     title            director  \
# 8085   s8086  TV Show           Station Horizon                 NaN
# 1948   s1949  TV Show               Van Helsing                 NaN
# 3192   s3193  TV Show                Eastsiders                 NaN
# 7831   s7832    Movie                   Rampant       Kim Sung-hoon
# 1981   s1982    Movie                   Whipped        Chandra Liow
# 579     s580    Movie              Midnight Run        Martin Brest
# 4280   s4281    Movie                 Imperfect         Steve Cheng
# 4734   s4735    Movie                   Tamasha          Imtiaz Ali
# 4714   s4715    Movie      Brij Mohan Amar Rahe  Nikhil Nagesh Bhat
# 4336   s4337    Movie  Crossroads: One Two Jaga             Nam Ron
#
#                                                    cast        country  \
# 8085  Bernard Yerlès, Roland Vouilloz, Gaspard Boesc...    Switzerland
# 1948  Kelly Overton, Jonathan Scarfe, Christopher He...  United States
# ...

# %%
df.shape # it shows the shape of dataset
# Out:
# (8807, 12)

# %%
df.columns # it shows the columns  in the dataset
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info() # it shows the data type of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()# it shows the mean meadian mode percentails
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.isnull().sum() # it shows the null data in a data set
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.duplicated() # it shows the duplicate data in the dataset
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
df.loc[10:20] # it shows the range of data
# Out:
#    show_id     type                                              title  \
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# 12     s13    Movie                                       Je Suis Karl
# 13     s14    Movie                   Confessions of an Invisible Girl
# 14     s15  TV Show                    Crime Stories: India Detectives
# 15     s16  TV Show                                  Dear White People
# 16     s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17     s18  TV Show                                    Falsa identidad
# 18     s19    Movie                                          Intrusion
# 19     s20  TV Show                                             Jaguar
# 20     s21  TV Show    Monsters Inside: The 24 Faces of Billy Milligan
#
#                                          director  \
# 10                                            NaN
# ...

# %%
df.type.value_counts() #IT SHOWS THE VALUE OF THE DATASET
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
df.groupby(by=["director","title"]).size() # it shows the grouped items in the dataset
# Out:
# director             title
# A. L. Vijay          Abhinetri                1
#                      Watchman                 1
# A. Raajdheep         Asura Guru               1
# A. Salaam            Salaakhen                1
# A.R. Murugadoss      Sarkar                   1
#                                              ..
# Óskar Thór Axelsson  Ég man þig               1
# Ömer Faruk Sorak     Aşk Tesadüfleri Sever    1
#                      G.O.R.A                  1
# Şenol Sönmez         Hayat Öpücügü            1
#                      Kill Me If You Dare      1
# Length: 6173, dtype: int64

# %%
df.sort_values(by="release_year",inplace=True,ascending=False) # it udes to sort the dataset
df
# Out:
#      show_id     type                                          title  \
# 993     s994  TV Show                                Shadow and Bone
# 361     s362  TV Show                                        Charmed
# 691     s692  TV Show                                So Not Worth It
# 74       s75  TV Show      The World's Most Amazing Vacation Rentals
# 487     s488  TV Show                           The Cook of Castamar
# ...      ...      ...                                            ...
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8205   s8206    Movie                           The Battle of Midway
# 7790   s7791    Movie                                 Prelude to War
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#          director                                               cast  \
# ...
